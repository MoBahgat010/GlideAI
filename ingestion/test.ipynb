# %%
from langchain_opendataloader_pdf import OpenDataLoaderPDFLoader


loader = OpenDataLoaderPDFLoader(
            file_path=["./test/large.pdf"],
            format="json",
            image_output="embedded",
            image_format="png",
            table_method="cluster",
            # hybrid="docling-fast",
            hybrid_mode="auto",
            # hybrid_url="http://localhost:5002",
            split_pages=False,
            quiet=False,
        )

loaded_data = loader.load()
# Out:
# Error running opendataloader-pdf CLI.
# Return code: 1
# Error during conversion: Command '['java', '-Djava.awt.headless=true', '-Dapple.awt.UIElement=true', '-jar', '/media/bahgat/bahgat/DEPI Data Science/Deep Learning/llm_engineering/.venv/lib/python3.12/site-packages/opendataloader_pdf/jar/opendataloader-pdf-cli.jar', './test/large.pdf', '--output-dir', '/tmp/tmp6lqvqfch', '--format', 'json', '--table-method', 'cluster', '--image-output', 'embedded', '--image-format', 'png', '--hybrid-mode', 'auto']' returned non-zero exit status 1.
# Jul 26, 2026 7:47:08 PM org.opendataloader.pdf.cli.CLIMain processPath
# WARNING: File or folder /media/bahgat/bahgat/DEPI Data Science/Deep Learning/llm_engineering/GraphRAG/ingestion/./test/large.pdf not found.
