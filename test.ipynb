# %%
from datasets import load_dataset
from huggingface_hub import login

login(token="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")

ds = load_dataset("SALT-NLP/Design2Code")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Resolving data files:   0%|          | 0/485 [00:00<?, ?it/s]

# %%
ds.save_to_disk("webpages")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/485 [00:00<?, ? examples/s]

# %%
print(ds["train"][0])
# Out:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x1206 at 0x79A1AC028170>}
